# %%
import pandas as pd
import numpy as np

# %%
path = "2024-barometre-consommation.xlsx"
df = pd.read_excel(path)

# %%
second_path = "2024-datamap.xlsx"
df_2 = pd.read_excel(second_path)

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'ID'
# 'sys_ElapsedTime'
# 'SEXE'
# 'AGE'
# 'QSEXE'
# 'RAGE1'
# 'RAGE2'
# 'RAGE3'
# 'AGGLOIFOP0'
# 'AGGLO'
# 'AGGLOIFOP2'
# 'TYPCOM'
# 'TAILCOM'
# 'DPT'
# 'REG'
# 'REG2'
# 'REG3'
# 'REG22'
# 'REG13'
# 'REG12'
# 'SITI'
# 'PPIA'
# 'RECPPIA'
# 'PI11'
# 'PI12'
# 'PI1'
# 'STC'
# 'PI2'
# 'TITC'
# 'STCA'
# 'STCB'
# 'STCC'
# 'PI3'
# 'PI4'
# 'STATUT'
# 'STATU1'
# 'STATU2'
# 'STATU3'
# 'SITC'
# 'PCFA'
# 'PCF1'
# 'PCF3'
# 'PCF4'
# 'FOYER'
# 'ENF'
# 'AGENF_1'
# 'AGENF_2'
# 'AGENF_3'
# 'AGENF_4'
# 'AGENF_5'
# 'AGENF_6'
# 'AGENF_7'
# 'AGENF_8'
# 'AGENF_9'
# 'AGENF_10'
# 'AGENF_11'
# 'AGENF_12'
# 'AGENF_13'
# 'AGENF_14'
# 'AGENF_15'
# 'AGENF_16'
# 'AGENF_17'
# 'RS6'
# 'QRS6'
# 'CELLULE'
# 'CELSEXE'
# 'CELAGE'
# 'CELAGE3'
# 'CELREG'
# 'CELREG3'
# 'CELAGGLO'
# 'CELAGGLO2'
# 'CELPCF1'
# 'CELPCF4'
# 'CELPI1'
# 'CELPI4'
# 'CELQRS6'
# 'Q1_1'
# 'Q1_2'
# 'Q1_3'
# 'Q1_4'
# 'Q1_5'
# 'Q1_6'
# 'Q1_7'
# 'Q1_8'
# 'Q1_9'
# 'Q1_10'
# 'Q1_11'
# 'Q1_12'
# 'Q1_13'
# 'Q1_14'
# 'Q2_r1'
# 'Q2_r2'
# 'Q2_r3'
# 'Q2_r4'
# ...

# %%
for col in df_2.columns:
    print(repr(col))
# Out:
# 'HEADER LEVEL'
# 'NAME'
# 'FILE'
# 'TYPE'
# 'WIDTH'
# 'FIRST_LINE'
# 'LAST_LINE'
# 'DELIMITER'
# 'WORKSHEET'
# 'LITERALS'
# 'RECORD_ID'
# 'WEIGHT'
# 'FILTER'
# 'QUALIFIER'
# 'ENCODING'
